# %%
# %% %matplotlib inline
import os
from time import sleep

import matplotlib.pyplot as plt
import numpy as np
import qcodes as qc
from qcodes import (
    Measurement,
    experiments,
    initialise_database,
    initialise_or_create_database_at,
    load_by_guid,
    load_by_run_spec,
    load_experiment,
    load_last_experiment,
    load_or_create_experiment,
    new_experiment,
)
from qcodes.dataset.plotting import plot_dataset, plot_by_id
# %%
import matplotlib.gridspec as gridspec

plt.rcParams['figure.figsize'] = [6.0, 4.0]
plt.rcParams['figure.dpi'] = 150

# %%
initialise_or_create_database_at('F:\QCoDeSLocal\SpinQubit\database\IMEC_AL809789_D18_D3SD4_T4.db')

# %%
fig = plt.figure()
gs1 = gridspec.GridSpec(10,10)

ax=fig.add_subplot(gs1[:,:])

ID = 1
gate_name = 'source'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 2
gate_name = 'AccS'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 3
gate_name = 'LB'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 4
gate_name = 'RB'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 5
gate_name = 'STbot'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 6
gate_name = 'AccD'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 7
gate_name = 'drain'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 8
gate_name = 'C'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 9
gate_name = 'G1'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 10
gate_name = 'G2'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 11
gate_name = 'G3'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 12
gate_name = 'G4'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 13
gate_name = 'R'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ID = 14
gate_name = 'Res'
axes1,colorbar1 = plot_by_id(ID,axes=ax, label=f"{gate_name} ID#{ID}")

ax.set_xlabel('V (mV)',size=14)
ax.set_ylabel('current (pA)',size=14)
ax.tick_params(labelsize=14) 
ax.set_title('T4 ~55 mK - IMEC AL809789 D18 D3SD7  QBBE4 ',size=14)
ax.grid()

ax.legend(fontsize=14)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

fig.tight_layout()
fig.savefig('QBBE4.png')
