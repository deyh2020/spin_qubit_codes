# %%
# %% %matplotlib inline
import os
from time import sleep

import matplotlib.pyplot as plt
import numpy as np
import qcodes as qc
from qcodes import (
    Measurement,
    experiments,
    initialise_database,
    initialise_or_create_database_at,
    load_by_guid,
    load_by_run_spec,
    load_experiment,
    load_last_experiment,
    load_or_create_experiment,
    new_experiment,
)
from qcodes.dataset.plotting import plot_dataset, plot_by_id
# %%
import matplotlib.gridspec as gridspec

plt.rcParams['figure.figsize'] = [6.0, 4.0]
plt.rcParams['figure.dpi'] = 150

# %%
initialise_or_create_database_at("/Users/fabrizioberr/Dropbox/Triton 4/fabrizio qdev dropbox/imec AL809789 D18 D3SD7 QLSI/210623_room temperature/IMEC_AL809789_D3SD7.db")

# %%
# %%
fig = plt.figure()
gs1 = gridspec.GridSpec(10,10)

ax=fig.add_subplot(gs1[:,:])
axes1,colorbar1 = plot_by_id(135,axes=ax, label='QBB16_1_6 #1, LB, RB @ 2 V ID#135')
axes1,colorbar1 = plot_by_id(138,axes=ax, label='QBB16_2_6 #1, LB, RB @ 2 V ID#138')
axes1,colorbar1 = plot_by_id(141,axes=ax, label='QBB16_3_6 #1, LB, RB @ 2 V ID#141')


ax.set_xlabel(' Top gate (V)',size=12)
ax.set_ylabel(' Source current (pA)',size=12)
ax.tick_params(labelsize=12) 
ax.set_title('IMEC_AL809789_D3SD7 - RT probe station, Source ~ 10 mV, drain grounded- FB',size=10)
ax.grid()

ax.legend(fontsize=10)

# %%
# %%
fig = plt.figure()
gs1 = gridspec.GridSpec(10,10)

ax=fig.add_subplot(gs1[:,:])
axes1,colorbar1 = plot_by_id(137,axes=ax, label='QBB16_1_6 #1, LB, RB @ 2 V ID#137')
axes1,colorbar1 = plot_by_id(139,axes=ax, label='QBB16_2_6 #1, LB, RB @ 2 V ID#139')


ax.set_xlabel(' Top gate (V)',size=12)
ax.set_ylabel(' Top gate current (pA)',size=12)
ax.tick_params(labelsize=12) 
ax.set_title('IMEC_AL809789_D3SD7 - RT probe station, Source ~ 10 mV, drain grounded- FB',size=10)
ax.grid()

ax.legend(fontsize=12)

# %%
experiments()
# Out:
# [RT probe station - imec AL809789 D18 D3/SD7 #QBB16_1_6#1@/Users/fabrizioberr/Dropbox/Triton 4/fabrizio qdev dropbox/imec AL809789 D18 D3SD7 QLSI/210623_room temperature/IMEC_AL809789_D3SD7.db
#  -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------,
#  RT probe station - imec AL809789 D18 D3/SD7#D3SD7 QBB16_1_6#2@/Users/fabrizioberr/Dropbox/Triton 4/fabrizio qdev dropbox/imec AL809789 D18 D3SD7 QLSI/210623_room temperature/IMEC_AL809789_D3SD7.db
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------,
#  RT probe station - imec AL809789 D18 #D3SD7 QBB16_1_6#3@/Users/fabrizioberr/Dropbox/Triton 4/fabrizio qdev dropbox/imec AL809789 D18 D3SD7 QLSI/210623_room temperature/IMEC_AL809789_D3SD7.db
# ...
